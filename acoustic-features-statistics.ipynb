# %% [markdown]
# <a href="https://www.kaggle.com/code/olgatasenko/acoustic-features-statistics?scriptVersionId=167847079" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip install opensmile
# Out:
# Collecting opensmile
#   Downloading opensmile-2.5.0-py3-none-manylinux_2_17_x86_64.whl.metadata (15 kB)
# Collecting audobject>=0.6.1 (from opensmile)
#   Downloading audobject-0.7.11-py3-none-any.whl.metadata (2.6 kB)
# Collecting audinterface>=0.7.0 (from opensmile)
#   Downloading audinterface-1.1.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting audformat<2.0.0,>=1.0.1 (from audinterface>=0.7.0->opensmile)
#   Downloading audformat-1.1.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting audiofile>=1.3.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audiofile-1.4.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting audmath>=1.3.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audmath-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting audresample<2.0.0,>=1.1.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audresample-1.3.3-py3-none-manylinux_2_17_x86_64.whl.metadata (4.4 kB)
# Collecting audeer>=1.18.0 (from audobject>=0.6.1->opensmile)
#   Downloading audeer-2.0.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from audobject>=0.6.1->opensmile) (6.11.0)
# Collecting oyaml (from audobject>=0.6.1->opensmile)
#   Downloading oyaml-1.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from audobject>=0.6.1->opensmile) (21.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from audeer>=1.18.0->audobject>=0.6.1->opensmile) (4.66.1)
# Collecting iso-639 (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile)
#   Downloading iso-639-0.4.5.tar.gz (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.4/167.4 kB 1.6 MB/s eta 0:00:00
# done
# Collecting iso3166 (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile)
#   Downloading iso3166-2.1.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pyyaml>=5.4.1 in /opt/conda/lib/python3.10/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (6.0.1)
# Requirement already satisfied: pandas>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.26.4)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (0.12.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=4.8.0->audobject>=0.6.1->opensmile) (3.17.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->audobject>=0.6.1->opensmile) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2023.4)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2.21)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (1.16.0)
# Downloading opensmile-2.5.0-py3-none-manylinux_2_17_x86_64.whl (996 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 996.2/996.2 kB 9.0 MB/s eta 0:00:00
# Downloading audinterface-1.1.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 3.0 MB/s eta 0:00:00
# Downloading audobject-0.7.11-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.9 MB/s eta 0:00:00
# Downloading audeer-2.0.0-py3-none-any.whl (39 kB)
# Downloading audformat-1.1.2-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 6.4 MB/s eta 0:00:00
# Downloading audiofile-1.4.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.7 MB/s eta 0:00:00
# Downloading audmath-1.4.0-py3-none-any.whl (23 kB)
# Downloading audresample-1.3.3-py3-none-manylinux_2_17_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.4/138.4 kB 6.8 MB/s eta 0:00:00
# Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Downloading iso3166-2.1.1-py3-none-any.whl (9.8 kB)
# Building wheels for collected packages: iso-639
# done
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=168840 sha256=c442de120a3fde8e04e0036afedb8e8d22c32e115e6e94d5f3c9c10d55fc44ee
#   Stored in directory: /root/.cache/pip/wheels/d8/78/cc/5478ca3b1c3f602eae6f8cdbd78f909c0a0bfa0bbcb5c7771f
# Successfully built iso-639
# Installing collected packages: iso-639, oyaml, iso3166, audresample, audmath, audeer, audobject, audiofile, audformat, audinterface, opensmile
# Successfully installed audeer-2.0.0 audformat-1.1.2 audinterface-1.1.0 audiofile-1.4.0 audmath-1.4.0 audobject-0.7.11 audresample-1.3.3 iso-639-0.4.5 iso3166-2.1.1 opensmile-2.5.0 oyaml-1.0

# %%
import os
import time

import numpy as np
import pandas as pd

import audiofile
import opensmile
from pathlib import Path
from scipy. stats import ttest_ind, mannwhitneyu
from numpy.random import seed
from numpy.random import randn
from scipy.stats import shapiro
from statistics import mean

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.Functionals,
)
features_names = smile.feature_names

# %%
def get_features(file_path):
    signal, sampling_rate = audiofile.read(file_path, always_2d=True)
    result = smile.process_signal(signal, sampling_rate)
    return list(result.iloc[0])

# %%
p = Path("/kaggle/input/control-preprocessed")
control_features = []

for x in p.iterdir():
    result = get_features(str(x)) 
    control_features.append(result)

# %%
p = Path("/kaggle/input/patients-prepocessed")
patients_features = []

for x in p.iterdir():
    result = get_features(str(x)) 
    patients_features.append(result)

# %%
control_df = pd.DataFrame(control_features, columns = features_names, dtype = float)

patient_df = pd.DataFrame(patients_features, columns = features_names, dtype = float)

# %%
patient_df = patient_df[['F0semitoneFrom27.5Hz_sma3nz_amean','F0semitoneFrom27.5Hz_sma3nz_stddevNorm',
    'loudness_sma3_amean','loudness_sma3_stddevNorm', 'spectralFlux_sma3_amean',
    'spectralFlux_sma3_stddevNorm', 'mfcc1_sma3_amean', 'mfcc1_sma3_stddevNorm', 'mfcc2_sma3_amean', 
    'mfcc2_sma3_stddevNorm','mfcc3_sma3_amean', 'mfcc3_sma3_stddevNorm', 'jitterLocal_sma3nz_amean',
    'jitterLocal_sma3nz_stddevNorm', 'shimmerLocaldB_sma3nz_amean','shimmerLocaldB_sma3nz_stddevNorm',
    'F1frequency_sma3nz_amean','F1frequency_sma3nz_stddevNorm', 'F1bandwidth_sma3nz_amean',
    'F1bandwidth_sma3nz_stddevNorm', 'F2frequency_sma3nz_amean','F2frequency_sma3nz_stddevNorm', 
    'F2bandwidth_sma3nz_amean','F2bandwidth_sma3nz_stddevNorm', 'F3frequency_sma3nz_amean',
    'F3frequency_sma3nz_stddevNorm', 'F3bandwidth_sma3nz_amean','F3bandwidth_sma3nz_stddevNorm']]

control_df = control_df[['F0semitoneFrom27.5Hz_sma3nz_amean','F0semitoneFrom27.5Hz_sma3nz_stddevNorm',
    'loudness_sma3_amean','loudness_sma3_stddevNorm', 'spectralFlux_sma3_amean',
    'spectralFlux_sma3_stddevNorm', 'mfcc1_sma3_amean', 'mfcc1_sma3_stddevNorm', 'mfcc2_sma3_amean', 
    'mfcc2_sma3_stddevNorm','mfcc3_sma3_amean', 'mfcc3_sma3_stddevNorm', 'jitterLocal_sma3nz_amean',
    'jitterLocal_sma3nz_stddevNorm', 'shimmerLocaldB_sma3nz_amean','shimmerLocaldB_sma3nz_stddevNorm',
    'F1frequency_sma3nz_amean','F1frequency_sma3nz_stddevNorm', 'F1bandwidth_sma3nz_amean',
    'F1bandwidth_sma3nz_stddevNorm', 'F2frequency_sma3nz_amean','F2frequency_sma3nz_stddevNorm', 
    'F2bandwidth_sma3nz_amean','F2bandwidth_sma3nz_stddevNorm', 'F3frequency_sma3nz_amean',
    'F3frequency_sma3nz_stddevNorm', 'F3bandwidth_sma3nz_amean','F3bandwidth_sma3nz_stddevNorm']]

# %%
def get_shapiro(df):
    for column in control_df.columns:
        p = list(shapiro(df[column]))[1]
        if p < 0.05:
            distr = 'abnormal distribution'
        else:
            distr = 'normal distribution'
        print(f'feature-{column}, {shapiro(df[column])}, {distr}')

# %%
print("Control group")
get_shapiro(control_df)
# Out:
# Control group
# feature-F0semitoneFrom27.5Hz_sma3nz_amean, ShapiroResult(statistic=0.8793644905090332, pvalue=6.682593367557388e-10), abnormal distribution
# feature-F0semitoneFrom27.5Hz_sma3nz_stddevNorm, ShapiroResult(statistic=0.9666851758956909, pvalue=0.0008425374398939312), abnormal distribution
# feature-loudness_sma3_amean, ShapiroResult(statistic=0.9652227163314819, pvalue=0.0006011640070937574), abnormal distribution
# feature-loudness_sma3_stddevNorm, ShapiroResult(statistic=0.9895291924476624, pvalue=0.3042009770870209), normal distribution
# feature-spectralFlux_sma3_amean, ShapiroResult(statistic=0.9556195139884949, pvalue=7.470006676157936e-05), abnormal distribution
# feature-spectralFlux_sma3_stddevNorm, ShapiroResult(statistic=0.9777666330337524, pvalue=0.013128820806741714), abnormal distribution
# feature-mfcc1_sma3_amean, ShapiroResult(statistic=0.991223156452179, pvalue=0.45557141304016113), normal distribution
# feature-mfcc1_sma3_stddevNorm, ShapiroResult(statistic=0.9479124546051025, pvalue=1.62145406648051e-05), abnormal distribution
# feature-mfcc2_sma3_amean, ShapiroResult(statistic=0.9593501091003418, pvalue=0.00016365561168640852), abnormal distribution
# feature-mfcc2_sma3_stddevNorm, ShapiroResult(statistic=0.3369113802909851, pvalue=1.4966123943446475e-23), abnormal distribution
# feature-mfcc3_sma3_amean, ShapiroResult(statistic=0.9826332330703735, pvalue=0.04831922799348831), abnormal distribution
# feature-mfcc3_sma3_stddevNorm, ShapiroResult(statistic=0.2169385552406311, pvalue=3.155452249050198e-25), abnormal distribution
# feature-jitterLocal_sma3nz_amean, ShapiroResult(statistic=0.9366242289543152, pvalue=2.100726987919188e-06), abnormal distribution
# feature-jitterLocal_sma3nz_stddevNorm, ShapiroResult(statistic=0.9793023467063904, pvalue=0.019706955179572105), abnormal distribution
# feature-shimmerLocaldB_sma3nz_amean, ShapiroResult(statistic=0.933942973613739, pvalue=1.331345060862077e-06), abnormal distribution
# feature-shimmerLocaldB_sma3nz_stddevNorm, ShapiroResult(statistic=0.9813308715820312, pvalue=0.03395593911409378), abnormal distribution
# feature-F1frequency_sma3nz_amean, ShapiroResult(statistic=0.9605302214622498, pvalue=0.0002111326903104782), abnormal distribution
# feature-F1frequency_sma3nz_stddevNorm, ShapiroResult(statistic=0.9740685224533081, pvalue=0.005058670416474342), abnormal distribution
# feature-F1bandwidth_sma3nz_amean, ShapiroResult(statistic=0.9885880947113037, pvalue=0.23953217267990112), normal distribution
# feature-F1bandwidth_sma3nz_stddevNorm, ShapiroResult(statistic=0.9830119013786316, pvalue=0.053555928170681), normal distribution
# feature-F2frequency_sma3nz_amean, ShapiroResult(statistic=0.9884024858474731, pvalue=0.22830432653427124), normal distribution
# feature-F2frequency_sma3nz_stddevNorm, ShapiroResult(statistic=0.985783040523529, pvalue=0.11373468488454819), normal distribution
# feature-F2bandwidth_sma3nz_amean, ShapiroResult(statistic=0.9905946254730225, pvalue=0.39409497380256653), normal distribution
# feature-F2bandwidth_sma3nz_stddevNorm, ShapiroResult(statistic=0.9923046231269836, pvalue=0.5741817951202393), normal distribution
# feature-F3frequency_sma3nz_amean, ShapiroResult(statistic=0.9830891489982605, pvalue=0.05469309911131859), normal distribution
# feature-F3frequency_sma3nz_stddevNorm, ShapiroResult(statistic=0.9823039174079895, pvalue=0.04418724775314331), abnormal distribution
# feature-F3bandwidth_sma3nz_amean, ShapiroResult(statistic=0.9891433119773865, pvalue=0.27607613801956177), normal distribution
# feature-F3bandwidth_sma3nz_stddevNorm, ShapiroResult(statistic=0.9541864991188049, pvalue=5.5719345255056396e-05), abnormal distribution

# %%
print("Patient group")
get_shapiro(patient_df)
# Out:
# Patient group
# feature-F0semitoneFrom27.5Hz_sma3nz_amean, ShapiroResult(statistic=0.8216565251350403, pvalue=1.8168646925484366e-12), abnormal distribution
# feature-F0semitoneFrom27.5Hz_sma3nz_stddevNorm, ShapiroResult(statistic=0.8727807402610779, pvalue=3.1324323690462563e-10), abnormal distribution
# feature-loudness_sma3_amean, ShapiroResult(statistic=0.9283051490783691, pvalue=5.270752012620505e-07), abnormal distribution
# feature-loudness_sma3_stddevNorm, ShapiroResult(statistic=0.9806365370750427, pvalue=0.02816202864050865), abnormal distribution
# feature-spectralFlux_sma3_amean, ShapiroResult(statistic=0.9821790456771851, pvalue=0.042715828865766525), abnormal distribution
# feature-spectralFlux_sma3_stddevNorm, ShapiroResult(statistic=0.9902067184448242, pvalue=0.35925811529159546), normal distribution
# feature-mfcc1_sma3_amean, ShapiroResult(statistic=0.9898251295089722, pvalue=0.32735055685043335), normal distribution
# feature-mfcc1_sma3_stddevNorm, ShapiroResult(statistic=0.9107458591461182, pvalue=3.750400878743676e-08), abnormal distribution
# feature-mfcc2_sma3_amean, ShapiroResult(statistic=0.98641437292099, pvalue=0.13485047221183777), normal distribution
# feature-mfcc2_sma3_stddevNorm, ShapiroResult(statistic=0.2936173677444458, pvalue=3.506735214892542e-24), abnormal distribution
# feature-mfcc3_sma3_amean, ShapiroResult(statistic=0.988540530204773, pvalue=0.23660831153392792), normal distribution
# feature-mfcc3_sma3_stddevNorm, ShapiroResult(statistic=0.16149526834487915, pvalue=6.191530121617827e-26), abnormal distribution
# feature-jitterLocal_sma3nz_amean, ShapiroResult(statistic=0.9048171639442444, pvalue=1.6493970633746358e-08), abnormal distribution
# feature-jitterLocal_sma3nz_stddevNorm, ShapiroResult(statistic=0.9929863214492798, pvalue=0.6545650362968445), normal distribution
# feature-shimmerLocaldB_sma3nz_amean, ShapiroResult(statistic=0.9227096438407898, pvalue=2.1870481248242868e-07), abnormal distribution
# feature-shimmerLocaldB_sma3nz_stddevNorm, ShapiroResult(statistic=0.988134503364563, pvalue=0.2129218429327011), normal distribution
# feature-F1frequency_sma3nz_amean, ShapiroResult(statistic=0.984978973865509, pvalue=0.09145614504814148), normal distribution
# feature-F1frequency_sma3nz_stddevNorm, ShapiroResult(statistic=0.9782505035400391, pvalue=0.014912357553839684), abnormal distribution
# feature-F1bandwidth_sma3nz_amean, ShapiroResult(statistic=0.9876660704612732, pvalue=0.18828216195106506), normal distribution
# feature-F1bandwidth_sma3nz_stddevNorm, ShapiroResult(statistic=0.9898132681846619, pvalue=0.3263934552669525), normal distribution
# feature-F2frequency_sma3nz_amean, ShapiroResult(statistic=0.9868659973144531, pvalue=0.1522163599729538), normal distribution
# feature-F2frequency_sma3nz_stddevNorm, ShapiroResult(statistic=0.9830697774887085, pvalue=0.05440586805343628), normal distribution
# feature-F2bandwidth_sma3nz_amean, ShapiroResult(statistic=0.9826337099075317, pvalue=0.048325199633836746), abnormal distribution
# feature-F2bandwidth_sma3nz_stddevNorm, ShapiroResult(statistic=0.9920945167541504, pvalue=0.550075888633728), normal distribution
# feature-F3frequency_sma3nz_amean, ShapiroResult(statistic=0.9852691888809204, pvalue=0.09895359724760056), normal distribution
# feature-F3frequency_sma3nz_stddevNorm, ShapiroResult(statistic=0.9889041185379028, pvalue=0.2597799003124237), normal distribution
# feature-F3bandwidth_sma3nz_amean, ShapiroResult(statistic=0.9917051792144775, pvalue=0.5066564083099365), normal distribution
# feature-F3bandwidth_sma3nz_stddevNorm, ShapiroResult(statistic=0.9895167350769043, pvalue=0.3032571077346802), normal distribution

# %% [markdown]
# # Независимый двухвыборочный t-тест для нормального распределения

# %%
def t_test(name, col_name):
    p = list(ttest_ind(patient_df[col_name], control_df[col_name]))[1]
    if p < 0.05:
        diff = 'mean is different'
    else:
        diff = 'no differences'
             
    print(f'{name}: {ttest_ind(patient_df[col_name], control_df[col_name])}, {diff}')

# %%
t_test('mfcc1_mean', 'mfcc1_sma3_amean')
t_test('F2frequency_mean', 'F2frequency_sma3nz_amean')
t_test('F2frequency_sd', 'F2frequency_sma3nz_stddevNorm')
t_test('F2bandwidth_sd', 'F2bandwidth_sma3nz_stddevNorm')
t_test('F3frequency_mean', 'F3frequency_sma3nz_amean')
t_test('F3bandwidth_mean', 'F3bandwidth_sma3nz_amean')
# Out:
# mfcc1_mean: TtestResult(statistic=-3.801112872702837, pvalue=0.00017362142128705596, df=308.0), mean is different
# F2frequency_mean: TtestResult(statistic=3.8698244490715417, pvalue=0.00013296862154480368, df=308.0), mean is different
# F2frequency_sd: TtestResult(statistic=-1.3399271785406877, pvalue=0.1812567245501101, df=308.0), no differences
# F2bandwidth_sd: TtestResult(statistic=1.7082996661609482, pvalue=0.08858826323877239, df=308.0), no differences
# F3frequency_mean: TtestResult(statistic=5.268842666745581, pvalue=2.5850299201933537e-07, df=308.0), mean is different
# F3bandwidth_mean: TtestResult(statistic=-2.31341206130135, pvalue=0.02135831993949111, df=308.0), mean is different

# %% [markdown]
# Поскольку p-значение меньше 0,05, мы отклоняем нулевую гипотезу t-критерия и делаем вывод, что имеется достаточно доказательств того, что два метода приводят к разным средним баллам за экзамен.

# %% [markdown]
# # U-тест Манна-Уитни для ненормального распределения

# %%
control_new = control_df.drop(columns=['mfcc1_sma3_amean', 'F2frequency_sma3nz_amean', 
                            'F2frequency_sma3nz_stddevNorm', 'F2bandwidth_sma3nz_stddevNorm',
                            'F3frequency_sma3nz_amean', 'F3bandwidth_sma3nz_amean'])

patients_new = patient_df.drop(columns=['mfcc1_sma3_amean', 'F2frequency_sma3nz_amean', 
                            'F2frequency_sma3nz_stddevNorm', 'F2bandwidth_sma3nz_stddevNorm',
                            'F3frequency_sma3nz_amean', 'F3bandwidth_sma3nz_amean'])

# %%
control_new.to_csv('control_new.csv')
patients_new.to_csv('patients_new.csv')

# %%
def u_test(col_name):
    p = list(mannwhitneyu(patient_df[col_name], control_df[col_name]))[1]
    if p < 0.05:
        diff = 'mean is different'
    else:
        diff = 'no differences'
             
    print(f'{col_name}: {mannwhitneyu(patient_df[col_name], control_df[col_name])}, {diff}')

# %%
for column in control_new.columns:
    u_test(column)
# Out:
# F0semitoneFrom27.5Hz_sma3nz_amean: MannwhitneyuResult(statistic=14845.0, pvalue=0.00033196440226642055), mean is different
# F0semitoneFrom27.5Hz_sma3nz_stddevNorm: MannwhitneyuResult(statistic=6864.0, pvalue=6.843396336087512e-11), mean is different
# loudness_sma3_amean: MannwhitneyuResult(statistic=8710.0, pvalue=2.8564627601884714e-05), mean is different
# loudness_sma3_stddevNorm: MannwhitneyuResult(statistic=19396.0, pvalue=8.245240847394584e-21), mean is different
# spectralFlux_sma3_amean: MannwhitneyuResult(statistic=10227.0, pvalue=0.023689568358288258), mean is different
# spectralFlux_sma3_stddevNorm: MannwhitneyuResult(statistic=17521.0, pvalue=2.94598470467322e-12), mean is different
# mfcc1_sma3_stddevNorm: MannwhitneyuResult(statistic=17332.0, pvalue=1.5756270598083485e-11), mean is different
# mfcc2_sma3_amean: MannwhitneyuResult(statistic=15612.0, pvalue=5.090929565030815e-06), mean is different
# mfcc2_sma3_stddevNorm: MannwhitneyuResult(statistic=11980.0, pvalue=0.9676518279842155), no differences
# mfcc3_sma3_amean: MannwhitneyuResult(statistic=14588.0, pvalue=0.0011012590922613893), mean is different
# mfcc3_sma3_stddevNorm: MannwhitneyuResult(statistic=11748.0, pvalue=0.7379520003946819), no differences
# jitterLocal_sma3nz_amean: MannwhitneyuResult(statistic=6240.0, pvalue=2.576810825091193e-13), mean is different
# jitterLocal_sma3nz_stddevNorm: MannwhitneyuResult(statistic=16462.0, pvalue=1.718283317461791e-08), mean is different
# shimmerLocaldB_sma3nz_amean: MannwhitneyuResult(statistic=10769.0, pvalue=0.11519843991425728), no differences
# shimmerLocaldB_sma3nz_stddevNorm: MannwhitneyuResult(statistic=10095.0, pvalue=0.015123412553050214), mean is different
# F1frequency_sma3nz_amean: MannwhitneyuResult(statistic=12630.0, pvalue=0.43425992620059883), no differences
# F1frequency_sma3nz_stddevNorm: MannwhitneyuResult(statistic=10973.0, pvalue=0.18793163737539487), no differences
# F1bandwidth_sma3nz_amean: MannwhitneyuResult(statistic=12001.0, pvalue=0.988877628139506), no differences
# F1bandwidth_sma3nz_stddevNorm: MannwhitneyuResult(statistic=9336.0, pvalue=0.0006956462893329394), mean is different
# F2bandwidth_sma3nz_amean: MannwhitneyuResult(statistic=10413.0, pvalue=0.04272284718005404), mean is different
# F3frequency_sma3nz_stddevNorm: MannwhitneyuResult(statistic=9025.0, pvalue=0.0001534498363348325), mean is different
# F3bandwidth_sma3nz_stddevNorm: MannwhitneyuResult(statistic=13147.0, pvalue=0.1506850729617595), no differences

# %% [markdown]
# # Some

# %%
for column in control_df.columns:
    print(f"""Control:{column}, max={max(control_df[column])}, min={min(control_df[column])}, mean={mean(control_df[column])}""")
# Out:
# Control:F0semitoneFrom27.5Hz_sma3nz_amean, max=39.55133056640625, min=22.928234100341797, mean=33.47360676180932
# Control:F0semitoneFrom27.5Hz_sma3nz_stddevNorm, max=0.38527029752731323, min=0.1363452970981598, mean=0.22726975121805745
# Control:loudness_sma3_amean, max=1.8605456352233887, min=0.4378761053085327, mean=0.9920047342777252
# Control:loudness_sma3_stddevNorm, max=1.2191081047058105, min=0.5916155576705933, mean=0.853443782560287
# Control:spectralFlux_sma3_amean, max=2.15478253364563, min=0.2584802210330963, mean=0.917884825506518
# Control:spectralFlux_sma3_stddevNorm, max=1.4397013187408447, min=0.7677875757217407, mean=1.095979489818696
# Control:mfcc1_sma3_amean, max=32.53364562988281, min=12.12855052947998, mean=22.04869991425545
# Control:mfcc1_sma3_stddevNorm, max=1.7172499895095825, min=0.5512177348136902, mean=0.9651531050282139
# Control:mfcc2_sma3_amean, max=26.535226821899414, min=-12.596908569335938, mean=7.127539436951761
# Control:mfcc2_sma3_stddevNorm, max=69.19572448730469, min=-107.59320831298828, mean=0.9395263581506668
# Control:mfcc3_sma3_amean, max=27.081357955932617, min=-7.197137832641602, mean=8.62364908646672
# Control:mfcc3_sma3_stddevNorm, max=97.84429931640625, min=-520.219970703125, mean=-5.519762321249131
# Control:jitterLocal_sma3nz_amean, max=0.0895511582493782, min=0.022868283092975616, mean=0.04964255426199205
# Control:jitterLocal_sma3nz_stddevNorm, max=2.4643123149871826, min=1.2128413915634155, mean=1.8172874035373812
# Control:shimmerLocaldB_sma3nz_amean, max=1.9663609266281128, min=1.0541726350784302, mean=1.4417344424032397
# Control:shimmerLocaldB_sma3nz_stddevNorm, max=1.0423648357391357, min=0.5930480360984802, mean=0.8301575641478262
# Control:F1frequency_sma3nz_amean, max=740.7260131835938, min=518.9443969726562, mean=631.9205767231603
# Control:F1frequency_sma3nz_stddevNorm, max=0.6314493417739868, min=0.27273431420326233, mean=0.4077200166640743
# Control:F1bandwidth_sma3nz_amean, max=1324.314208984375, min=1008.6610717773438, mean=1207.1587666173134
# Control:F1bandwidth_sma3nz_stddevNorm, max=0.36544233560562134, min=0.19416600465774536, mean=0.2610047894139444
# Control:F2frequency_sma3nz_amean, max=1913.13232421875, min=1533.451416015625, mean=1698.3461937689012
# Control:F2frequency_sma3nz_stddevNorm, max=0.2559945285320282, min=0.15565593540668488, mean=0.19805803423927676
# Control:F2bandwidth_sma3nz_amean, max=1070.51318359375, min=780.8284301757812, mean=931.11495125063
# Control:F2bandwidth_sma3nz_stddevNorm, max=0.5746885538101196, min=0.2950855791568756, mean=0.42108486121700656
# Control:F3frequency_sma3nz_amean, max=2997.5263671875, min=2542.27490234375, mean=2792.663323777722
# Control:F3frequency_sma3nz_stddevNorm, max=0.16325215995311737, min=0.08405240625143051, mean=0.12060910900754314
# Control:F3bandwidth_sma3nz_amean, max=1037.0369873046875, min=628.7845458984375, mean=857.3348274477066
# Control:F3bandwidth_sma3nz_stddevNorm, max=0.7436073422431946, min=0.3055858612060547, mean=0.4836161159699963

# %%
for column in patient_df.columns:
    print(f"""Patient:{column}, max={max(patient_df[column])}, min={min(patient_df[column])}, mean={mean(patient_df[column])}""")
# Out:
# Patient:F0semitoneFrom27.5Hz_sma3nz_amean, max=41.8543701171875, min=20.99978256225586, mean=34.50545594000047
# Patient:F0semitoneFrom27.5Hz_sma3nz_stddevNorm, max=0.3797951638698578, min=0.08663035929203033, mean=0.19465882393621628
# Patient:loudness_sma3_amean, max=1.9355812072753906, min=0.34227150678634644, mean=0.8458803697939842
# Patient:loudness_sma3_stddevNorm, max=1.4434866905212402, min=0.6841607689857483, mean=1.0171214918936453
# Patient:spectralFlux_sma3_amean, max=1.513218641281128, min=0.26061683893203735, mean=0.7844948205255693
# Patient:spectralFlux_sma3_stddevNorm, max=1.811147689819336, min=0.779425859451294, mean=1.2324210636077388
# Patient:mfcc1_sma3_amean, max=35.336700439453125, min=9.755379676818848, mean=20.19762268066406
# Patient:mfcc1_sma3_stddevNorm, max=2.421015977859497, min=0.6279579401016235, mean=1.1836319046635781
# Patient:mfcc2_sma3_amean, max=22.119691848754883, min=-0.8351825475692749, mean=11.150012541586353
# Patient:mfcc2_sma3_stddevNorm, max=39.16627883911133, min=-67.03321075439453, mean=1.3285414384257408
# Patient:mfcc3_sma3_amean, max=24.736766815185547, min=-4.960203647613525, mean=10.892018552028365
# Patient:mfcc3_sma3_stddevNorm, max=238.50877380371094, min=-12.357726097106934, mean=4.232695828714679
# Patient:jitterLocal_sma3nz_amean, max=0.08766588568687439, min=0.019015030935406685, mean=0.03832226280243166
# Patient:jitterLocal_sma3nz_stddevNorm, max=2.575392007827759, min=1.3612782955169678, mean=1.9809580733699184
# Patient:shimmerLocaldB_sma3nz_amean, max=2.1120617389678955, min=1.043440580368042, mean=1.3955790519714355
# Patient:shimmerLocaldB_sma3nz_stddevNorm, max=1.1393985748291016, min=0.539806604385376, mean=0.8086925456600804
# Patient:F1frequency_sma3nz_amean, max=772.62939453125, min=501.3357238769531, mean=638.0110266900832
# Patient:F1frequency_sma3nz_stddevNorm, max=0.5808292031288147, min=0.21389147639274597, mean=0.3975077859817013
# Patient:F1bandwidth_sma3nz_amean, max=1413.020751953125, min=1079.945556640625, mean=1208.1697021484374
# Patient:F1bandwidth_sma3nz_stddevNorm, max=0.33955198526382446, min=0.1819508671760559, mean=0.24831526981246088
# Patient:F2frequency_sma3nz_amean, max=1912.9822998046875, min=1538.7008056640625, mean=1731.569054782006
# Patient:F2frequency_sma3nz_stddevNorm, max=0.2623550593852997, min=0.14029592275619507, mean=0.194454474026157
# Patient:F2bandwidth_sma3nz_amean, max=1136.5406494140625, min=773.68701171875, mean=919.7451148248488
# Patient:F2bandwidth_sma3nz_stddevNorm, max=0.6177182793617249, min=0.2855163514614105, mean=0.4309318138707069
# Patient:F3frequency_sma3nz_amean, max=3016.283203125, min=2629.267822265625, mean=2845.3778367565524
# Patient:F3frequency_sma3nz_stddevNorm, max=0.15565811097621918, min=0.0824638232588768, mean=0.1135003748920656
# Patient:F3bandwidth_sma3nz_amean, max=1012.9386596679688, min=682.0850830078125, mean=839.0003232894405
# Patient:F3bandwidth_sma3nz_stddevNorm, max=0.6409830451011658, min=0.32263919711112976, mean=0.4898917090508246
